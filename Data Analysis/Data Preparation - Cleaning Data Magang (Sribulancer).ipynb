# %% [markdown]
# ## **Data Cleaning**
#
# *   Check Data Types
# *   Change Data Types
# *   Renaming Columns
# *   Check Duplicates

# %%
df_fl.head()
# Out:
#       masked_id         dob                     created_at         city  \
# 0  cef12173997c  2000-02-02  2019-10-13 11:34:30.171 +0700       Malang
# 1  4f82e3d571d3  2001-08-19  2019-07-01 16:56:54.611 +0700       Malang
# 2  7372b6ad847f  1988-03-15  2017-01-08 11:10:21.988 +0700  DKI Jakarta
# 3  a23182cb3f86  1985-12-06  2015-12-16 10:39:40.694 +0700       Malang
# 4  af3657ab5395  1988-04-20  2017-03-22 11:54:32.550 +0700        Bogor
#
#   gender  fl_requested_help  fl_workspace_reviewed  fl_applications_submitted  \
# 0      f                 12                     64                         23
# 1      m                 10                     14                        307
# 2      m                 84                    309                       2506
# 3      f                 82                    205                        829
# 4      f                  0                      4                        108
#
# ...

# %%
df_fl.dtypes
# Out:
# masked_id                     object
# dob                           object
# created_at                    object
# city                          object
# gender                        object
# fl_requested_help              int64
# fl_workspace_reviewed          int64
# fl_applications_submitted      int64
# fl_applications_rejected       int64
# fl_workspaces_ongoing          int64
# fl_workspaces_closed           int64
# fl_workspaces_cancelled        int64
# fl_rating_avg                float64
# fl_rating_comm               float64
# fl_rating_quality            float64
# fl_rating_time               float64
# dtype: object

# %%
change_columns_fl = ['dob','created_at']
for cc in change_columns_fl :
  df_fl[cc] = pd.to_datetime(df_fl[cc])

# %%
df_fl.dtypes
# Out:
# masked_id                                                   object
# dob                                                 datetime64[ns]
# created_at                   datetime64[ns, pytz.FixedOffset(420)]
# city                                                        object
# gender                                                      object
# fl_requested_help                                            int64
# fl_workspace_reviewed                                        int64
# fl_applications_submitted                                    int64
# fl_applications_rejected                                     int64
# fl_workspaces_ongoing                                        int64
# fl_workspaces_closed                                         int64
# fl_workspaces_cancelled                                      int64
# fl_rating_avg                                              float64
# fl_rating_comm                                             float64
# ...

# %%
df_fl.rename(columns={'masked_id':'fl_masked_id',
                      'dob':'fl_dob',
                      'created_at':'fl_created_at',
                      'city':'fl_city',
                      'gender':'fl_gender'}, inplace=True)

# %%
df_fl = df_fl.dropna()

# %%
df_fl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1431 entries, 0 to 1431
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   fl_masked_id               1431 non-null   object
#  1   fl_dob                     1431 non-null   datetime64[ns]
#  2   fl_created_at              1431 non-null   datetime64[ns, pytz.FixedOffset(420)]
#  3   fl_city                    1431 non-null   object
#  4   fl_gender                  1431 non-null   object
#  5   fl_requested_help          1431 non-null   int64
#  6   fl_workspace_reviewed      1431 non-null   int64
#  7   fl_applications_submitted  1431 non-null   int64
#  8   fl_applications_rejected   1431 non-null   int64
#  9   fl_workspaces_ongoing      1431 non-null   int64
#  10  fl_workspaces_closed       1431 non-null   int64
#  11  fl_workspaces_cancelled    1431 non-null   int64
#  12  fl_rating_avg              1431 non-null   float64
# ...

# %%
df_fl.groupby('fl_applications_rejected').size()
# Out:
# fl_applications_rejected
# 0     166
# 1     168
# 2      97
# 3      54
# 4     122
# 5      63
# 6      50
# 7      35
# 8      43
# 9      19
# 10     20
# 11     31
# 12     67
# 13    174
# 14      5
# 16     17
# 17      9
# 18     14
# 19      5
# 20    110
# 22     75
# 23      4
# 25     12
# 26     25
# 32      1
# 33     27
# 38      5
# 53     12
# 58      1
# dtype: int64

# %%
df_fl.head()
# Out:
#    fl_masked_id     fl_dob                    fl_created_at      fl_city  \
# 0  cef12173997c 2000-02-02 2019-10-13 11:34:30.171000+07:00       Malang
# 1  4f82e3d571d3 2001-08-19 2019-07-01 16:56:54.611000+07:00       Malang
# 2  7372b6ad847f 1988-03-15 2017-01-08 11:10:21.988000+07:00  DKI Jakarta
# 3  a23182cb3f86 1985-12-06 2015-12-16 10:39:40.694000+07:00       Malang
# 4  af3657ab5395 1988-04-20 2017-03-22 11:54:32.550000+07:00        Bogor
#
#   fl_gender  fl_requested_help  fl_workspace_reviewed  \
# 0         f                 12                     64
# 1         m                 10                     14
# 2         m                 84                    309
# 3         f                 82                    205
# 4         f                  0                      4
#
#    fl_applications_submitted  fl_applications_rejected  fl_workspaces_ongoing  \
# 0                         23                         1                     -1
# ...

# %%
df_fl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1431 entries, 0 to 1431
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   fl_masked_id               1431 non-null   object
#  1   fl_dob                     1431 non-null   datetime64[ns]
#  2   fl_created_at              1431 non-null   datetime64[ns, pytz.FixedOffset(420)]
#  3   fl_city                    1431 non-null   object
#  4   fl_gender                  1431 non-null   object
#  5   fl_requested_help          1431 non-null   int64
#  6   fl_workspace_reviewed      1431 non-null   int64
#  7   fl_applications_submitted  1431 non-null   int64
#  8   fl_applications_rejected   1431 non-null   int64
#  9   fl_workspaces_ongoing      1431 non-null   int64
#  10  fl_workspaces_closed       1431 non-null   int64
#  11  fl_workspaces_cancelled    1431 non-null   int64
#  12  fl_rating_avg              1431 non-null   float64
# ...

# %%
df_job.head()
# Out:
#       masked_id                     created_at  \
# 0  49535c68d41e  2022-09-26 15:27:02.644 +0700
# 1  cee07735782b  2022-10-02 21:26:08.447 +0700
# 2  8ea85237e263  2022-09-12 23:59:41.230 +0700
# 3  2a19d6ad26be  2022-10-04 18:18:32.701 +0700
# 4  70ed88284a4c  2022-09-21 08:17:33.989 +0700
#
#                            cname_id  freelancer_budget   budget   amount  \
# 0                       desain-logo                  0   300000   300000
# 1                entri-data-lainnya                  1        0  2500000
# 2  desain-kartu-nama-dan-stationery                  0  2000000  2000000
# 3                entri-data-lainnya                  1        0   250000
# 4                       desain-logo                  0   350000   350000
#
#   job_type  applied_number  hired_number               name
# 0  Private               1             1  Makanan & Minuman
# 1   Public               5             1              Other
# ...

# %%
change_columns = ['created_at']
for cc in change_columns :
  df_job[cc] = pd.to_datetime(df_job[cc])

# %%
df_job.rename(columns={'masked_id':'job_masked_id',
                       'cname_id':'job_category',
                       'name':'job_industry',
                       'created_at':'job_created_at',
                       'budget':'job_budget',
                       'amount':'job_amount'}, inplace=True)

# %%
df_job.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1327 entries, 0 to 1326
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   job_masked_id      1327 non-null   object
#  1   job_created_at     1327 non-null   datetime64[ns, pytz.FixedOffset(420)]
#  2   job_category       1327 non-null   object
#  3   freelancer_budget  1327 non-null   int64
#  4   job_budget         1327 non-null   int64
#  5   job_amount         1327 non-null   int64
#  6   job_type           1327 non-null   object
#  7   applied_number     1327 non-null   int64
#  8   hired_number       1327 non-null   int64
#  9   job_industry       1327 non-null   object
# dtypes: datetime64[ns, pytz.FixedOffset(420)](1), int64(5), object(4)
# memory usage: 103.8+ KB

# %%
df_job.drop_duplicates(subset='job_masked_id')
# Out:
#      job_masked_id                   job_created_at  \
# 0     49535c68d41e 2022-09-26 15:27:02.644000+07:00
# 1     cee07735782b 2022-10-02 21:26:08.447000+07:00
# 2     8ea85237e263 2022-09-12 23:59:41.230000+07:00
# 3     2a19d6ad26be 2022-10-04 18:18:32.701000+07:00
# 4     70ed88284a4c 2022-09-21 08:17:33.989000+07:00
# ...            ...                              ...
# 1317  326a758c6490 2022-02-03 01:55:10.240000+07:00
# 1319  c12eb260967a 2022-01-31 11:27:22.687000+07:00
# 1323  08d6fdcd8bf0 2022-02-03 08:40:43.192000+07:00
# 1324  78805baae732 2022-02-01 12:51:26.903000+07:00
# 1326  0a86ec07f20d 2022-02-14 10:01:28.655000+07:00
#
#                           job_category  freelancer_budget  job_budget  \
# 0                          desain-logo                  0      300000
# 1                   entri-data-lainnya                  1           0
# 2     desain-kartu-nama-dan-stationery                  0     2000000
# ...

# %%
df_ja.head()
# Out:
#       masked_id                     created_at   masked_id.1         fl_id  \
# 0  3ea9b89f5efd  2022-03-11 22:31:15.988 +0700  42b9fc8dd0e0  633d52ebac12
# 1  f97d7c3c3bec  2022-03-11 22:47:51.676 +0700  b06c3769cf75  5c070c0c01dc
# 2  b4bc24e21a8e  2022-03-11 22:50:05.945 +0700  05e70dcb6f0b  5c070c0c01dc
# 3  2f0c33160405  2022-03-11 23:00:17.635 +0700  05e70dcb6f0b  24d4c104f5f6
# 4  5e202f11fd3e  2022-03-11 21:22:51.920 +0700  7f1f0f547563  a0b51fd2e73a
#
#      amount  freelancer_payable_amount  comission_amount  shortlisted  \
# 0  25000000                   22500000           2500000            0
# 1     70000                      63000              7000            0
# 2     70000                      63000              7000            0
# 3     70000                      63000              7000            0
# 4    350000                     315000             35000            0
#
#    is_private  hired
# 0           0  False
# 1           0  False
# 2           0  False
# ...

# %%
change_columns_ja = ['created_at']
for cc in change_columns_ja :
  df_ja[cc] = pd.to_datetime(df_ja[cc])

# %%
df_ja.rename(columns={'masked_id':'ja_masked_id',
                      'created_at':'ja_created_at',
                      'masked_id.1':'ja_cl_id',
                      'fl_id':'ja_fl_id',
                      'amount':'ja_amount',
                      'freelancer_payable_amount':'ja_fl_payable_amount'}, inplace=True)

# %%
df_ja.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44232 entries, 0 to 44231
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ja_masked_id          44232 non-null  object
#  1   ja_created_at         44232 non-null  datetime64[ns, pytz.FixedOffset(420)]
#  2   ja_cl_id              44232 non-null  object
#  3   ja_fl_id              44157 non-null  object
#  4   ja_amount             44232 non-null  int64
#  5   ja_fl_payable_amount  44232 non-null  int64
#  6   comission_amount      44232 non-null  int64
#  7   shortlisted           44232 non-null  int64
#  8   is_private            44232 non-null  int64
#  9   hired                 44232 non-null  bool
# dtypes: bool(1), datetime64[ns, pytz.FixedOffset(420)](1), int64(5), object(3)
# memory usage: 3.1+ MB

# %%
df_cl.head()
# Out:
#       masked_id         dob                     created_at      city gender  \
# 0  7e457e67659f  1989-01-01  2022-09-26 15:21:29.479 +0700       NaN    NaN
# 1  4a244b65c0a2  1988-09-19  2019-09-20 10:25:14.527 +0700       NaN      f
# 2  cea8d20f1549  1977-04-09  2022-09-12 23:40:59.440 +0700       NaN    NaN
# 3  691feb07cd24  1991-03-16  2018-07-04 09:34:02.778 +0700       NaN      m
# 4  0a282df36f9e  1988-03-22  2021-05-24 17:27:43.214 +0700  Surabaya      m
#
#                 name  cl_requested_help  cl_reviewed  cl_jobs_posted  \
# 0  Makanan & Minuman                  0            0               1
# 1              Other                  0            7              25
# 2    Home Furnishing                  0            0               2
# 3           Internet                 13          924             622
# 4  Makanan & Minuman                  1            6               7
#
#    cl_jobs_approved  cl_jobs_cancelled  cl_invoices_qty  \
# ...

# %%
change_columns_cl = ['dob','created_at']
for cc in change_columns_cl :
  df_cl[cc] = pd.to_datetime(df_cl[cc])

# %%
df_cl.rename(columns={'masked_id':'cl_masked_id',
                      'dob':'cl_dob',
                      'created_at':'cl_created_at',
                      'city':'cl_city',
                      'gender':'cl_gender',
                      'name':'cl_industry'}, inplace=True)

# %%
df_cl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1432 entries, 0 to 1431
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   cl_masked_id               1402 non-null   object
#  1   cl_dob                     1432 non-null   datetime64[ns]
#  2   cl_created_at              1432 non-null   datetime64[ns, pytz.FixedOffset(420)]
#  3   cl_city                    138 non-null    object
#  4   cl_gender                  411 non-null    object
#  5   cl_industry                1432 non-null   object
#  6   cl_requested_help          1432 non-null   int64
#  7   cl_reviewed                1432 non-null   int64
#  8   cl_jobs_posted             1432 non-null   int64
#  9   cl_jobs_approved           1432 non-null   int64
#  10  cl_jobs_cancelled          1432 non-null   int64
#  11  cl_invoices_qty            1432 non-null   int64
#  12  cl_invoices_fullpaid_qty   1432 non-null   int64
# ...

# %%
df_cl = df_cl.dropna(subset=['cl_masked_id'])
df_cl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1402 entries, 0 to 1431
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   cl_masked_id               1402 non-null   object
#  1   cl_dob                     1402 non-null   datetime64[ns]
#  2   cl_created_at              1402 non-null   datetime64[ns, pytz.FixedOffset(420)]
#  3   cl_city                    136 non-null    object
#  4   cl_gender                  409 non-null    object
#  5   cl_industry                1402 non-null   object
#  6   cl_requested_help          1402 non-null   int64
#  7   cl_reviewed                1402 non-null   int64
#  8   cl_jobs_posted             1402 non-null   int64
#  9   cl_jobs_approved           1402 non-null   int64
#  10  cl_jobs_cancelled          1402 non-null   int64
#  11  cl_invoices_qty            1402 non-null   int64
#  12  cl_invoices_fullpaid_qty   1402 non-null   int64
# ...

# %%
df_ws.head()
# Out:
#       masked_id                     created_at        job_id         cl_id  \
# 0  7247a0a8ba28  2022-09-26 15:38:37.247 +0700  49535c68d41e  7e457e67659f
# 1  fadb4d59cece  2022-10-06 14:37:07.973 +0700  cee07735782b  4a244b65c0a2
# 2  72ccdd2581da  2022-10-07 14:32:58.838 +0700  8ea85237e263  cea8d20f1549
# 3  3409399a1568  2022-10-07 18:24:58.125 +0700  2a19d6ad26be  0a282df36f9e
# 4  439904de5ae1  2022-09-21 09:03:02.268 +0700  70ed88284a4c  6d9af8363fd6
#
#           fl_id   amount  freelancer_payable_amount  comission_amount  \
# 0  cef12173997c   300000                     270000             30000
# 1  4f82e3d571d3  2500000                    2250000            250000
# 2  7372b6ad847f  2000000                    1800000            200000
# 3  af3657ab5395   250000                     225000             25000
# 4  f714d266f129   350000                     280000             70000
#
#   flow_status closed_at
# 0      closed       NaN
# 1      closed       NaN
# ...

# %%
change_columns_ws = ['created_at']
for cc in change_columns_ws :
  df_ws[cc] = pd.to_datetime(df_ws[cc])

# %%
df_ws.rename(columns={'masked_id':'ws_masked_id',
                      'created_at':'ws_created_at',
                      'amount':'ws_amount',
                      'freelancer_payable_amount':'ws_fl_payable_amount'}, inplace=True)

# %%
df_ws.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2154 entries, 0 to 2153
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ws_masked_id          2154 non-null   object
#  1   ws_created_at         2154 non-null   datetime64[ns, pytz.FixedOffset(420)]
#  2   job_id                2154 non-null   object
#  3   cl_id                 2154 non-null   object
#  4   fl_id                 2154 non-null   object
#  5   ws_amount             2154 non-null   int64
#  6   ws_fl_payable_amount  2154 non-null   int64
#  7   comission_amount      2154 non-null   int64
#  8   flow_status           2154 non-null   object
#  9   closed_at             1584 non-null   object
# dtypes: datetime64[ns, pytz.FixedOffset(420)](1), int64(3), object(6)
# memory usage: 168.4+ KB
